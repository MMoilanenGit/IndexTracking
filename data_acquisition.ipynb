# %%
# Analyse and Track index US banks
# Take Tickers from files and create similar index. Track changes


# Check tracking error
# https://www.investopedia.com/terms/t/trackingerror.asp

# Between TFC,USB,PNC,FRC,FITB,SIVB,MTB,RF,KEY,CFG = 10 most active in iShares U.S. Regional Banks ETF (IAT)

# Maybe from here smthng too
# https://www.ishares.com/uk/individual/en/products/297140/ishares-s-p-u-s-banks-ucits-etf-usd-acc-fund

# %%
import yfinance as yf
import pandas as pd

#v = yf.download("IAT TFC USB PNC FRC FITB SIVB MTB RF KEY CFG", start="2020-11-09", end="2020-11-14",interval= "1m")

data= yf.download("frc", start="2005-01-01", end="2020-10-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-09   27.250000   28.110001   26.990000   27.920000   21.694521
# 2010-12-10   27.400000   27.719999   27.059999   27.410000   21.298229
# 2010-12-13   27.500000   27.719999   27.000000   27.400000   21.290466
# 2010-12-14   27.700001   27.969999   27.020000   27.309999   21.220526
# 2010-12-15   27.200001   27.700001   27.190001   27.450001   21.329311
# ...                ...         ...         ...         ...         ...
# 2020-10-26  129.460007  129.759995  127.379997  128.669998  128.465363
# 2020-10-27  128.179993  128.690002  125.519997  125.750000  125.550003
# 2020-10-28  123.529999  125.529999  122.830002  123.800003  123.800003
# 2020-10-29  123.660004  125.800003  122.730003  125.180000  125.180000
# 2020-10-30  124.949997  126.750000  124.320000  126.139999  126.139999
#
#               Volume
# Date
# 2010-12-09  10609700
# 2010-12-10   1206800
# 2010-12-13    473200
# ...

# %%
data_1m_week46.to_csv("data_1m_week46")

# %%
bank_daily = yf.download("IAT TFC USB PNC FRC FITB SIVB MTB RF KEY CFG", start="2005-01-01", end="2020-10-31")
# Out:
# [*********************100%***********************]  11 of 11 completed

# %%
bank_daily.to_csv("banks012005102020")

# %%
bank_daily
# Out:
#             Adj Close                                               \
#                   CFG       FITB         FRC        IAT        KEY
# Date
# 2004-12-31        NaN  29.844439         NaN        NaN  21.403625
# 2005-01-03        NaN  30.002159         NaN        NaN  21.113186
# 2005-01-04        NaN  29.787624         NaN        NaN  21.024794
# 2005-01-05        NaN  29.308092         NaN        NaN  20.885897
# 2005-01-06        NaN  29.188213         NaN        NaN  20.696480
# ...               ...        ...         ...        ...        ...
# 2020-10-26  27.970001  23.450001  128.465363  37.090000  13.000000
# 2020-10-27  26.660000  22.910000  125.550003  35.849998  12.630000
# 2020-10-28  25.879999  22.440001  123.800003  35.189999  12.400000
# 2020-10-29  26.709999  23.100000  125.180000  35.970001  12.750000
# 2020-10-30  27.250000  23.219999  126.139999  36.529999  12.980000
#
#                                                                       ...  \
# ...

# %%
bank_daily.columns
# Out:
# MultiIndex([('Adj Close',  'CFG'),
#             ('Adj Close', 'FITB'),
#             ('Adj Close',  'FRC'),
#             ('Adj Close',  'IAT'),
#             ('Adj Close',  'KEY'),
#             ('Adj Close',  'MTB'),
#             ('Adj Close',  'PNC'),
#             ('Adj Close',   'RF'),
#             ('Adj Close', 'SIVB'),
#             ('Adj Close',  'TFC'),
#             ('Adj Close',  'USB'),
#             (    'Close',  'CFG'),
#             (    'Close', 'FITB'),
#             (    'Close',  'FRC'),
#             (    'Close',  'IAT'),
#             (    'Close',  'KEY'),
#             (    'Close',  'MTB'),
#             (    'Close',  'PNC'),
#             (    'Close',   'RF'),
#             (    'Close', 'SIVB'),
#             (    'Close',  'TFC'),
#             (    'Close',  'USB'),
#             (     'High',  'CFG'),
#             (     'High', 'FITB'),
#             (     'High',  'FRC'),
#             (     'High',  'IAT'),
#             (     'High',  'KEY'),
# ...

# %%
bank_daily["Adj Close"].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c874ef75e095> in <module>()
# ----> 1 bank_daily["Adj Close"].plot()
#       2 plt.show()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
from matplotlib import pyplot

# %%
b2 = bank_daily["Adj Close"]
b2.index
# Out:
# DatetimeIndex(['2004-12-31', '2005-01-03', '2005-01-04', '2005-01-05',
#                '2005-01-06', '2005-01-07', '2005-01-10', '2005-01-11',
#                '2005-01-12', '2005-01-13',
#                ...
#                '2020-10-19', '2020-10-20', '2020-10-21', '2020-10-22',
#                '2020-10-23', '2020-10-26', '2020-10-27', '2020-10-28',
#                '2020-10-29', '2020-10-30'],
#               dtype='datetime64[ns]', name='Date', length=3987, freq=None)

# %%
b2.USB.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-d78d3bef8d2a> in <module>()
# ----> 1 b2.USB.plot()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
# ...

# %%
import matplotlib.dates as dates
plt_dates = dates.date2num(list(b2.index))

# %%
plt_dates
# Out:
# array([731946., 731949., 731950., ..., 737726., 737727., 737728.])

# %%
plt.(plt_dates,b2.FRC)
# Out:
#   File "<ipython-input-25-8fc8af3dfd76>", line 1
#     plt.(plt_dates,b2.FRC)
#         ^
# SyntaxError: invalid syntax
